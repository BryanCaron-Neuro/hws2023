# %% [markdown]
# # BigBrain data processing with CBRAIN and DataLad
#
# This tutorial introduces several infrastructure tools used in HIBALL:
# * <a href="#part1">Part I</a>: DataLad and Boutiques, to access and process BigBrain data through uniform command-line interfaces
# * <a href="#part2">Part II</a>: CBRAIN, to process BigBrain data on HPC clusters through a web portal

# %% [markdown]
# <div id="part1"/>
#
#
# ## Part I: accessing and reusing BigBrain data with DataLad and Boutiques
#
#
# This part of the tutorial will walk you through the following steps:
# 1. <a href="#finding">Finding BigBrain datasets in DataLad</a>
# 2. <a href="#installing">Installing and downloading BigBrain datasets</a>
# 3. <a href="#processing">Processing BigBrain datasets with Boutiques</a>
# 4. <a href="#adding">Uploading derived data to DataLad</a>
#
# The main tools and platforms involved in this tutorial are [DataLad](https://www.datalad.org), [Boutiques](http://boutiques.github.io), and the [Canadian Open Neuroscience Platform](http://portal.conp.ca). Please refer to the documentation of these tools for additional information.
#
# This tutorial notebook is available on Google Colab and can be done entirely online, without the need for any local software installation. Familiarity with Linux command lines is recommended but not required.
#
# Alternately, if you are familiar with the [Docker](http://docker.io) system and want to run the tutorial on your own computer, you can run all the commands of this tutorial in Docker image `glatard/hws`.

# %% [markdown]
# ### Software installation
#
# The following script installs the required software in the Google Colab environment:

# %%
# !git clone https://github.com/glatard/hws.git && (cd hws && ./install.sh)
# Out:
# Cloning into 'hws'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 177 (delta 0), reused 0 (delta 0), pack-reused 175
# Receiving objects: 100% (177/177), 4.92 MiB | 18.57 MiB/s, done.
# Resolving deltas: 100% (100/100), done.
# Installed Nilearn
# Downloaded Conda
# Installed Conda
# Installed git-annex
# Installed apt packages
# Installed DataLad and Boutiques
# Installed fslstats
# Configured Git

# %% [markdown]
# <div id="finding"/>
#
#
# ### Finding BigBrain datasets in DataLad
#
# One of our goals in [HIBALL](https://bigbrainproject.org/hiball.html) is to distribute BigBrain datasets through the uniform interface provided by DataLad. In this part of the tutorial, we will demonstrate how BigBrain data can be downloaded and manipulated using DataLad. A complete introduction to DataLad, including detailed tutorials, is available in the [DataLad handbook](http://handbook.datalad.org/en/latest/index.html).

# %% [markdown]
# BigBrain DataLad datasets are available through the web portal of the Canadian Open Neuroscience Platform, available at http://portal.conp.ca. They can be found by entering "BigBrain" in the search field:
#
# ![screenshot](https://github.com/bryancaron/hws/blob/master/figures/CONP-BigBrain-01-YRE-Oct2022.png?raw=1)
#
# https://portal.conp.ca/search?search=bigbrain&sortKey=conpStatus&sortComparitor=asc&page=1&max_per_page=10&cursor=0&limit=10

# %% [markdown]
# <div id="installing"/>
#
# ### Installing and downloading BigBrain datasets
#
# Once a dataset is identified, instructions on how to download it using DataLad are available in the corresponding dataset page in the CONP portal:
#
# ![screenshot](https://github.com/bryancaron/hws/blob/master/figures/CONP-BigBrain-03-YRE-Oct2022.png?raw=1)

# %% [markdown]
# The next steps will go through these instructions.

# %% [markdown]
# #### Dataset installation
#
# First, the CONP dataset should be installed to your local machine using `datalad install`:

# %%
# !datalad install https://github.com/CONP-PCNO/conp-dataset.git
# %cd conp-dataset
# Out:
# Clone attempt:   0% 0.00/2.00 [00:00<?, ? Candidate locations/s]
# Enumerating: 0.00 Objects [00:00, ? Objects/s]
#
# Counting:   0% 0.00/16.0 [00:00<?, ? Objects/s]
#
# Compressing:   0% 0.00/16.0 [00:00<?, ? Objects/s]
#
# Receiving:   0% 0.00/15.6k [00:00<?, ? Objects/s]
# Receiving:  27% 4.22k/15.6k [00:00<00:00, 40.1k Objects/s]
# Receiving:  53% 8.28k/15.6k [00:01<00:02, 3.65k Objects/s]
# Receiving:  65% 10.2k/15.6k [00:03<00:02, 2.27k Objects/s]
# Receiving:  72% 11.2k/15.6k [00:04<00:02, 2.10k Objects/s]
#
# Resolving:   0% 0.00/6.40k [00:00<?, ? Deltas/s]
# Resolving:  53% 3.39k/6.40k [00:00<00:00, 31.5k Deltas/s]
# [INFO   ] Remote origin not usable by git-annex; setting annex-ignore
# [INFO   ] https://github.com/CONP-PCNO/conp-dataset.git/config download failed: Not Found
# install(ok): /content/conp-dataset (dataset)
# /content/conp-dataset

# %% [markdown]
# The CONP DataLad dataset contains many datasets, located under `projects`:

# %%
# !ls projects
# Out:
# 1000GenomesProject
# BigBrain
# BigBrain_3DClassifiedVolumes
# BigBrain_3DROIs
# BigBrain_3DSurfaces
# BigBrain_A3D
# BigBrain_BigBrainWarp_Support
# BigBrain_Hippocampus_Segmentation
# BigBrain_Layer_Segmentation
# BigBrain_MRISIM
# BigBrain_Raw_Data
# BigBrain_Surface_Parcellations
# braincode_5P_Predicting_Persistent_Postconcussive_Problems_in_Pediatric
# braincode_CAN-BIND_Biomarkers_for_Depression_Baseline_Data_Release
# braincode_Epilepsy_Priority_Setting_Partnership
# braincode_fBIRN
# braincode_Mouse_Image
# braincode_NDD_Priority_Setting_Partnership
# braincode_ONDRI_Foundation_Study_Baseline_Data_Release
# braincode_POND_Registry_Clinical_Data_Release
# braincode_POND_Registry_Imaging_Data_Release
# Brainspan
# calgary-campinas
# Calgary_Preschool_MRI_Dataset
# celltypes
# CFMM_7T__MP2RAGE_T1_mapping
# CHBMP
# cneuromod
# Comparing_Perturbation_Modes_for_Evaluating_Instabilities_in_Neuroimaging__Processed_NKI_RS_Subset__08_2019_
# Intracellular_Recordings_of_Murine_Neocortical_Neurons
# Khanlab
# Learning_Naturalistic_Structure__Processed_fMRI_dataset
# Longitudinal_structural_MRI_and_behavioural_data_for_mice_prenatally_exposed_to_maternal_immune_activation_either_early_or_late_in_gestation
# mcgill-emc-rna-seq-experiment
# mica-mics
# mousebytes
# mousebytesdataset
# MRI_and_unbiased_averages_of_wild_muskrats__Ondatra_zibethicus__and_red_squirrels__Tamiasciurus_hudsonicus_
# multicenter-phantom
# Multimodal_data_with_wide_field_GCaMP_imaging
# Multi-model_functionalization_of_disease-associated_PTEN_missense_mutations
# Neurocon
# nhpatlas
# Numerically_Perturbed_Structural_Connectomes_from_100_individuals_in_the_NKI_Rockland_Dataset
# Open_Access__The_Effect_of_Neurorehabilitation_on_Multiple_Sclerosis___Unlocking_the_Resting_State_fMRI_Data
# openpain
# PERFORM_Dataset__one_control_subject
# preventad-open
# preventad-open-bids
# preventad-registered
# Quantifying_Neural_Cognitive_Relationships_Across_the_Brain
# refseq
# Reusing-Neuro-Data
# SIMON-dataset
# spins_travelling_phantoms
# Synthetic_Animated_Mouse__SAM___University_of_British_Columbia__Datasets_and_3D_models
# Systematic_phenomics_analysis_of_autism-associated_genes
# Taowu
# VFA_T1_mapping___RTHawk__open__vs_Siemens__commercial_
# visual-working-memory

# %% [markdown]
# The specific BigBrain dataset of interest in this tutorial can be installed as follows:

# %%
# !datalad install projects/BigBrain
# Out:
# Clone attempt:   0% 0.00/4.00 [00:00<?, ? Candidate locations/s]
# Enumerating: 0.00 Objects [00:00, ? Objects/s]
#
# Counting:   0% 0.00/95.0 [00:00<?, ? Objects/s]
#
# Compressing:   0% 0.00/24.0 [00:00<?, ? Objects/s]
#
# Receiving:   0% 0.00/4.13k [00:00<?, ? Objects/s]
#
# Resolving:   0% 0.00/1.07k [00:00<?, ? Deltas/s]
# [INFO   ] Remote origin not usable by git-annex; setting annex-ignore
# [INFO   ] https://github.com/conpdatasets/bigbrain-datalad.git/config download failed: Not Found
# install(ok): /content/conp-dataset/projects/BigBrain (dataset) [Installed subdataset in order to get /content/conp-dataset/projects/BigBrain]

# %% [markdown]
# Importantly, this step does not download the data. Instead, it installs a set of links that could be downloaded at a later stage. Feel free to install any other dataset you might be interested in, this won't involve long transfer times!

# %% [markdown]
# This dataset contains the 40$\mu$m BigBrain blocks, in the Nifti and MINC formats:

# %%
# !ls projects/BigBrain/3D_Blocks/40um/*
# Out:
# projects/BigBrain/3D_Blocks/40um/mnc:
# block40-0001-inv.mnc  block40-0043-inv.mnc  block40-0085-inv.mnc
# block40-0002-inv.mnc  block40-0044-inv.mnc  block40-0086-inv.mnc
# block40-0003-inv.mnc  block40-0045-inv.mnc  block40-0087-inv.mnc
# block40-0004-inv.mnc  block40-0046-inv.mnc  block40-0088-inv.mnc
# block40-0005-inv.mnc  block40-0047-inv.mnc  block40-0089-inv.mnc
# block40-0006-inv.mnc  block40-0048-inv.mnc  block40-0090-inv.mnc
# block40-0007-inv.mnc  block40-0049-inv.mnc  block40-0091-inv.mnc
# block40-0008-inv.mnc  block40-0050-inv.mnc  block40-0092-inv.mnc
# block40-0009-inv.mnc  block40-0051-inv.mnc  block40-0093-inv.mnc
# block40-0010-inv.mnc  block40-0052-inv.mnc  block40-0094-inv.mnc
# block40-0011-inv.mnc  block40-0053-inv.mnc  block40-0095-inv.mnc
# block40-0012-inv.mnc  block40-0054-inv.mnc  block40-0096-inv.mnc
# block40-0013-inv.mnc  block40-0055-inv.mnc  block40-0097-inv.mnc
# block40-0014-inv.mnc  block40-0056-inv.mnc  block40-0098-inv.mnc
# block40-0015-inv.mnc  block40-0057-inv.mnc  block40-0099-inv.mnc
# block40-0016-inv.mnc  block40-0058-inv.mnc  block40-0100-inv.mnc
# block40-0017-inv.mnc  block40-0059-inv.mnc  block40-0101-inv.mnc
# block40-0018-inv.mnc  block40-0060-inv.mnc  block40-0102-inv.mnc
# block40-0019-inv.mnc  block40-0061-inv.mnc  block40-0103-inv.mnc
# block40-0020-inv.mnc  block40-0062-inv.mnc  block40-0104-inv.mnc
# block40-0021-inv.mnc  block40-0063-inv.mnc  block40-0105-inv.mnc
# block40-0022-inv.mnc  block40-0064-inv.mnc  block40-0106-inv.mnc
# block40-0023-inv.mnc  block40-0065-inv.mnc  block40-0107-inv.mnc
# block40-0024-inv.mnc  block40-0066-inv.mnc  block40-0108-inv.mnc
# block40-0025-inv.mnc  block40-0067-inv.mnc  block40-0109-inv.mnc
# block40-0026-inv.mnc  block40-0068-inv.mnc  block40-0110-inv.mnc
# block40-0027-inv.mnc  block40-0069-inv.mnc  block40-0111-inv.mnc
# block40-0028-inv.mnc  block40-0070-inv.mnc  block40-0112-inv.mnc
# block40-0029-inv.mnc  block40-0071-inv.mnc  block40-0113-inv.mnc
# block40-0030-inv.mnc  block40-0072-inv.mnc  block40-0114-inv.mnc
# block40-0031-inv.mnc  block40-0073-inv.mnc  block40-0115-inv.mnc
# block40-0032-inv.mnc  block40-0074-inv.mnc  block40-0116-inv.mnc
# block40-0033-inv.mnc  block40-0075-inv.mnc  block40-0117-inv.mnc
# block40-0034-inv.mnc  block40-0076-inv.mnc  block40-0118-inv.mnc
# block40-0035-inv.mnc  block40-0077-inv.mnc  block40-0119-inv.mnc
# block40-0036-inv.mnc  block40-0078-inv.mnc  block40-0120-inv.mnc
# block40-0037-inv.mnc  block40-0079-inv.mnc  block40-0121-inv.mnc
# block40-0038-inv.mnc  block40-0080-inv.mnc  block40-0122-inv.mnc
# block40-0039-inv.mnc  block40-0081-inv.mnc  block40-0123-inv.mnc
# block40-0040-inv.mnc  block40-0082-inv.mnc  block40-0124-inv.mnc
# block40-0041-inv.mnc  block40-0083-inv.mnc  block40-0125-inv.mnc
# block40-0042-inv.mnc  block40-0084-inv.mnc  legend1000.mnc
#
# projects/BigBrain/3D_Blocks/40um/nii:
# block40-0001-inv.nii.gz  block40-0043-inv.nii.gz  block40-0085-inv.nii.gz
# block40-0002-inv.nii.gz  block40-0044-inv.nii.gz  block40-0086-inv.nii.gz
# block40-0003-inv.nii.gz  block40-0045-inv.nii.gz  block40-0087-inv.nii.gz
# block40-0004-inv.nii.gz  block40-0046-inv.nii.gz  block40-0088-inv.nii.gz
# block40-0005-inv.nii.gz  block40-0047-inv.nii.gz  block40-0089-inv.nii.gz
# block40-0006-inv.nii.gz  block40-0048-inv.nii.gz  block40-0090-inv.nii.gz
# block40-0007-inv.nii.gz  block40-0049-inv.nii.gz  block40-0091-inv.nii.gz
# block40-0008-inv.nii.gz  block40-0050-inv.nii.gz  block40-0092-inv.nii.gz
# block40-0009-inv.nii.gz  block40-0051-inv.nii.gz  block40-0093-inv.nii.gz
# block40-0010-inv.nii.gz  block40-0052-inv.nii.gz  block40-0094-inv.nii.gz
# block40-0011-inv.nii.gz  block40-0053-inv.nii.gz  block40-0095-inv.nii.gz
# block40-0012-inv.nii.gz  block40-0054-inv.nii.gz  block40-0096-inv.nii.gz
# block40-0013-inv.nii.gz  block40-0055-inv.nii.gz  block40-0097-inv.nii.gz
# block40-0014-inv.nii.gz  block40-0056-inv.nii.gz  block40-0098-inv.nii.gz
# block40-0015-inv.nii.gz  block40-0057-inv.nii.gz  block40-0099-inv.nii.gz
# block40-0016-inv.nii.gz  block40-0058-inv.nii.gz  block40-0100-inv.nii.gz
# block40-0017-inv.nii.gz  block40-0059-inv.nii.gz  block40-0101-inv.nii.gz
# block40-0018-inv.nii.gz  block40-0060-inv.nii.gz  block40-0102-inv.nii.gz
# block40-0019-inv.nii.gz  block40-0061-inv.nii.gz  block40-0103-inv.nii.gz
# block40-0020-inv.nii.gz  block40-0062-inv.nii.gz  block40-0104-inv.nii.gz
# block40-0021-inv.nii.gz  block40-0063-inv.nii.gz  block40-0105-inv.nii.gz
# block40-0022-inv.nii.gz  block40-0064-inv.nii.gz  block40-0106-inv.nii.gz
# block40-0023-inv.nii.gz  block40-0065-inv.nii.gz  block40-0107-inv.nii.gz
# block40-0024-inv.nii.gz  block40-0066-inv.nii.gz  block40-0108-inv.nii.gz
# block40-0025-inv.nii.gz  block40-0067-inv.nii.gz  block40-0109-inv.nii.gz
# block40-0026-inv.nii.gz  block40-0068-inv.nii.gz  block40-0110-inv.nii.gz
# block40-0027-inv.nii.gz  block40-0069-inv.nii.gz  block40-0111-inv.nii.gz
# block40-0028-inv.nii.gz  block40-0070-inv.nii.gz  block40-0112-inv.nii.gz
# block40-0029-inv.nii.gz  block40-0071-inv.nii.gz  block40-0113-inv.nii.gz
# block40-0030-inv.nii.gz  block40-0072-inv.nii.gz  block40-0114-inv.nii.gz
# block40-0031-inv.nii.gz  block40-0073-inv.nii.gz  block40-0115-inv.nii.gz
# block40-0032-inv.nii.gz  block40-0074-inv.nii.gz  block40-0116-inv.nii.gz
# block40-0033-inv.nii.gz  block40-0075-inv.nii.gz  block40-0117-inv.nii.gz
# block40-0034-inv.nii.gz  block40-0076-inv.nii.gz  block40-0118-inv.nii.gz
# block40-0035-inv.nii.gz  block40-0077-inv.nii.gz  block40-0119-inv.nii.gz
# block40-0036-inv.nii.gz  block40-0078-inv.nii.gz  block40-0120-inv.nii.gz
# block40-0037-inv.nii.gz  block40-0079-inv.nii.gz  block40-0121-inv.nii.gz
# block40-0038-inv.nii.gz  block40-0080-inv.nii.gz  block40-0122-inv.nii.gz
# block40-0039-inv.nii.gz  block40-0081-inv.nii.gz  block40-0123-inv.nii.gz
# block40-0040-inv.nii.gz  block40-0082-inv.nii.gz  block40-0124-inv.nii.gz
# block40-0041-inv.nii.gz  block40-0083-inv.nii.gz  block40-0125-inv.nii.gz
# block40-0042-inv.nii.gz  block40-0084-inv.nii.gz  legend1000.nii.gz

# %% [markdown]
# It also contains reconstructed 3D volumes at various resolutions and in various spaces:

# %%
# !ls projects/BigBrain/3D_Volumes/*/*
# Out:
# projects/BigBrain/3D_Volumes/Histological_Space/mnc:
# full16_1000um_optbal.mnc  full16_400um_optbal.mnc  full8_300um_optbal.mnc
# full16_100um_optbal.mnc   full8_1000um_optbal.mnc  full8_400um_optbal.mnc
# full16_200um_optbal.mnc   full8_100um_optbal.mnc
# full16_300um_optbal.mnc   full8_200um_optbal.mnc
#
# projects/BigBrain/3D_Volumes/Histological_Space/nii:
# full16_1000um_optbal.nii.gz  full8_1000um_optbal.nii.gz
# full16_100um_optbal.nii.gz   full8_100um_optbal.nii.gz
# full16_200um_optbal.nii.gz   full8_200um_optbal.nii.gz
# full16_300um_optbal.nii.gz   full8_300um_optbal.nii.gz
# full16_400um_optbal.nii.gz   full8_400um_optbal.nii.gz
#
# projects/BigBrain/3D_Volumes/MNI-ADNI_Space/mnc:
# full16_100um_adni.mnc  full16_400um_adni.mnc  full8_300um_adni.mnc
# full16_200um_adni.mnc  full8_100um_adni.mnc   full8_400um_adni.mnc
# full16_300um_adni.mnc  full8_200um_adni.mnc   mni_adni_hi_t1w_tal_nlin_sym.mnc
#
# projects/BigBrain/3D_Volumes/MNI-ADNI_Space/nii:
# full16_100um_adni.nii.gz  full8_200um_adni.nii.gz
# full16_200um_adni.nii.gz  full8_300um_adni.nii.gz
# full16_300um_adni.nii.gz  full8_400um_adni.nii.gz
# full16_400um_adni.nii.gz  mni_adni_hi_t1w_tal_nlin_sym.nii.gz
# full8_100um_adni.nii.gz
#
# projects/BigBrain/3D_Volumes/MNI-ADNI_Space/transformation:
# bigbrain_to_adni_lin.xfm	bigbrain_to_adni_nl.xfm
# bigbrain_to_adni_nl_grid_0.mnc
#
# projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/mnc:
# full16_100um_2009b_sym.mnc  full8_200um_2009b_sym.mnc
# full16_200um_2009b_sym.mnc  full8_300um_2009b_sym.mnc
# full16_300um_2009b_sym.mnc  full8_400um_2009b_sym.mnc
# full16_400um_2009b_sym.mnc  mni_icbm152_t1_tal_nlin_sym_09b_hires.mnc
# full8_100um_2009b_sym.mnc
#
# projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii:
# full16_100um_2009b_sym.nii.gz  full8_200um_2009b_sym.nii.gz
# full16_200um_2009b_sym.nii.gz  full8_300um_2009b_sym.nii.gz
# full16_300um_2009b_sym.nii.gz  full8_400um_2009b_sym.nii.gz
# full16_400um_2009b_sym.nii.gz  mni_icbm152_t1_tal_nlin_sym_09b_hires.nii.gz
# full8_100um_2009b_sym.nii.gz
#
# projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/transformation:
# bigbrain_to_icbm2009b_lin.xfm	     bigbrain_to_icbm2009b_nl.xfm
# bigbrain_to_icbm2009b_nl_grid_0.mnc

# %% [markdown]
# #### Data download
#
# The actual data can be downloaded on demand, using `datalad get`:

# %%
# !datalad get projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.nii.gz
# Out:
# Total:   0% 0.00/21.3M [00:00<?, ? Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:   0% 0.00/21.3M [00:00<?, ? Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:   2% 340k/21.3M [00:00<00:30, 679k Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:   2% 438k/21.3M [00:01<00:52, 395k Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:   4% 938k/21.3M [00:01<00:30, 670k Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:  13% 2.83M/21.3M [00:02<00:09, 1.90M Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:  34% 7.36M/21.3M [00:02<00:03, 4.47M Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:  47% 10.1M/21.3M [00:03<00:02, 4.79M Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz:  69% 14.7M/21.3M [00:03<00:01, 6.26M Bytes/s]
# Get 3D_Volum .. b_sym.nii.gz: 100% 21.3M/21.3M [00:04<00:00, 8.46M Bytes/s]
# get(ok): projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.nii.gz (file) [from web...]
# action summary:
#   get (notneeded: 1, ok: 1)

# %% [markdown]
# The data is now available:

# %%
# %matplotlib inline
import nibabel as nib
import nilearn.plotting as nilp
im1 = nib.load('projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.nii.gz')
nilp.view_img(im1.slicer[100:200,100:200,100:200], bg_img=None, cmap='gray', resampling_interpolation='nearest')
# Out:
# /usr/local/lib/python3.7/dist-packages/nilearn/plotting/html_stat_map.py:113: UserWarning: Threshold given was 1e-06, but the data has no values below 257.0.
#   data.min()))
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
#   &lt;script&gt;
#     /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...

# %% [markdown]
# <div id="processing"/>
#
#
# ### Processing BigBrain datasets with Boutiques

# %% [markdown]
# <a href="https://docs.google.com/presentation/d/1w9SC6IMxhTneR1Mac3-RoF8_ps84XDMIexiwpU_0ERo" target="_blank">
#     <img src="https://github.com/glatard/hws/blob/master/figures/Boutiques.svg/?raw=1"></a>

# %% [markdown]
# #### How does Boutiques facilitate the processing of BigBrain ?
#
# Boutiques wraps around command-line tools to facilitate their porting to different environments.
# For instance, locally you might be processing BigBrain using an FSL [Docker](https://www.docker.com/)
# container. However, for security reasons, HPC environments use [Singularity](https://singularity.lbl.gov/)
# for containerization. While their command-lines are similar, you would still have to alter your script to
# enable use of both.
#
# Boutiques abstracts the interfacing with container technologies entirely. All you need is Boutiques installed
# (via `pip install boutiques`), a Boutiques tool, and an invocation file and you're ready to go!

# %% [markdown]
# #### What makes a tool a Boutiques tool?
#
# A Boutiques tool is any command line tool that is described within a descriptor file following the Boutiques json schema.
#
# The content of a Boutiques descriptor can be seen below:

# %%
# !bosh pprint zenodo.4472771
# Out:
# ================================================================================
#
# Tool name: fslstats (ver: 5.0.9)
# Tool description: Descriptor of fslstats from the FSL toolbox. Computes various statistics on nifti images.
# Tags: domain: neuroinformatics, mri; toolbox: FSL
#
# Command-line:
#   FSLOUTPUTTYPE=NIFTI_GZ fslstats [t] [INPUT_FILE] [l] [u] [r] [R] [e]
#                          [E] [v] [V] [m] [M] [s] [S] [w] [x] [X] [c]
#                          [C] [p] [P] [a] [n] [k] [d] [h] [H] >
#                          [OUTPUT_FILE]
#
# ================================================================================
#
# Input Groups:
# 	Name: Output Type
# 	Type: One is Required
# 	Group Member IDs: r, R, e, E, v, V, m, M, s, S, w, x, X, c, C, p, P, h, H
#
# ================================================================================
#
# optional arguments:
#   -t [T]
#     ID: t
#     Value Key: [t]
#     Type: Flag
#     List: False
#     Optional: True
#     Description: give a separate output line for each 3D volume of a 4D
#      timeseries
#   -l [L]
#     ID: l
#     Value Key: [l]
#     Type: Number
#     List: False
#     Optional: True
#     Integer: False
#     Range: [N/A, N/A]
#     Description: set lower threshold
#   -u [U]
#     ID: u
#     Value Key: [u]
#     Type: Number
#     List: False
#     Optional: True
#     Integer: False
#     Range: [N/A, N/A]
#     Description: set upper threshold
#   -r [R]
#     ID: r
#     Value Key: [r]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output <robust min intensity> <robust max intensity>
#   -R [R]
#     ID: R
#     Value Key: [R]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output <min intensity> <max intensity>
#   -e [E]
#     ID: e
#     Value Key: [e]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output mean entropy ; mean(-i*ln(i))
#   -E [E]
#     ID: E
#     Value Key: [E]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output mean entropy (of nonzero voxels)
#   -v [V]
#     ID: v
#     Value Key: [v]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output <voxels> <volume>
#   -V [V]
#     ID: V
#     Value Key: [V]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output <voxels> <volume> (for nonzero voxels)
#   -m [M]
#     ID: m
#     Value Key: [m]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output mean
#   -M [M]
#     ID: M
#     Value Key: [M]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output mean (for nonzero voxels)
#   -s [S]
#     ID: s
#     Value Key: [s]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output standard deviation
#   -S [S]
#     ID: S
#     Value Key: [S]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output standard deviation (for nonzero voxels)
#   -w [W]
#     ID: w
#     Value Key: [w]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output smallest ROI <xmin> <xsize> <ymin> <ysize> <zmin>
#      <zsize> <tmin> <tsize> containing nonzero voxels
#   -x [X]
#     ID: x
#     Value Key: [x]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output co-ordinates of maximum voxel
#   -X [X]
#     ID: X
#     Value Key: [X]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output co-ordinates of minimum voxel
#   -c [C]
#     ID: c
#     Value Key: [c]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output centre-of-gravity (cog) in mm coordinates
#   -C [C]
#     ID: C
#     Value Key: [C]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  output centre-of-gravity (cog) in voxel coordinates
#   -p [P]
#     ID: p
#     Value Key: [p]
#     Type: Number
#     List: False
#     Optional: True
#     Integer: True
#     Range: [N/A, 100]
#     Description:  output nth percentile (n between 0 and 100)
#   -P [P]
#     ID: P
#     Value Key: [P]
#     Type: Number
#     List: False
#     Optional: True
#     Integer: True
#     Range: [N/A, 100]
#     Description:  output nth percentile (for nonzero voxels)
#   -a [A]
#     ID: a
#     Value Key: [a]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  use absolute values of all image intensities
#   -n [N]
#     ID: n
#     Value Key: [n]
#     Type: Flag
#     List: False
#     Optional: True
#     Description:  treat NaN or Inf as zero for subsequent stats
#   -k [K]
#     ID: k
#     Value Key: [k]
#     Type: File
#     List: False
#     Optional: True
#     Description:  use the specified image (filename) for masking -
#      overrides lower and upper thresholds
#   -d [D]
#     ID: d
#     Value Key: [d]
#     Type: File
#     List: False
#     Optional: True
#     Description:  take the difference between the base image and the image
#      specified here
#   -h [H]
#     ID: h
#     Value Key: [h]
#     Type: Number
#     List: False
#     Optional: True
#     Integer: True
#     Range: [N/A, N/A]
#     Description:  output a histogram (for the thresholded/masked voxels
#      only) with nbins
#   -H [H]
#     ID: H
#     Value Key: [H]
#     Type: Number
#     List: True
#     Optional: True
#     List Length: 3 - 3
#     Integer: False
#     Range: [N/A, N/A]
#     Description:  output a histogram (for the thresholded/masked voxels
#      only) with nbins and histogram limits of min and max
#
# required arguments:
#   [INPUT_FILE]
#     ID: input_file
#     Value Key: [INPUT_FILE]
#     Type: File
#     List: False
#     Optional: False
#   [OUTPUT_FILE]
#     ID: output
#     Value Key: [OUTPUT_FILE]
#     Type: None
#     List: False
#     Optional: False
#
# ================================================================================
#
# Output Files:
#   Name: Output (Required)
# 	Format: [INPUT_FILE].txt
# 	Filename depends on Input IDs: input_file
# 	Stripped extensions (before substitution): .nii.gz, .nii

# %% [markdown]
# #### Steps to process data with Boutiques
#
# 1. `bosh search` your desired tool
# 2. use `bosh example` as a guide for creating a valid invocation for the tool
# 3. Launch the tool with the command `bosh exec launch`

# %% [markdown]
# #### BoSh search
#
# To facilitate search of the available tools published to Zenodo, a search functionality is built into the the **Bo**utiques **Sh**ell (bosh) command line interface.
#
# Let's take a look at what are the top 10 most pulled descriptors:

# %%
# !bosh search
# Out:
# [ INFO ] Showing 10 of 91 result(s), exluding 1 deprecated result(s).
# ID              TITLE                                    DESCRIPTION                                    DOWNLOADS
# zenodo.1482743  fsl_bet                                  Automated brain extraction tool for FSL            91083
# zenodo.4472771  fslstats                                 Descriptor of fslstats from the FSL tool...        30800
# zenodo.2587160  makeblastdb                              Application to create BLAST databases, v...         7158
# zenodo.2602109  MCFLIRT                                  MCFLIRT, as implemented in Nipype (modul...         3132
# zenodo.1451003  qeeg                                     qeeg application                                    3106
# zenodo.3699595  Dipy Tracking and Connectome Generation  Pipeline for generating streamlines and ...         3097
# zenodo.1895219  BIDS App - fmriprep                      fMRIprep is a functional magneticresonan...         3092
# zenodo.1445789  ICA_AROMA                                ICA-AROMA (i.e. Independent Component An...         3089
# zenodo.1451001  BIDS app example                         See https://github.com/BIDS-Apps/example            3087
# zenodo.1484547  BIDS App - FreeSurfer 6.0                BIDS App version of freesurfer 6.0, from...         3086

# %% [markdown]
# If we have a tool in mind, we can specify the name of the tool within our query to return descriptors with a matching name

# %%
# !bosh search fsl
# Out:
# [ INFO ] Showing 10 of 19 result(s), exluding 0 deprecated result(s).
# ID              TITLE                                   DESCRIPTION                                    DOWNLOADS
# zenodo.1482743  fsl_bet                                 Automated brain extraction tool for FSL            91083
# zenodo.4472771  fslstats                                Descriptor of fslstats from the FSL tool...        30800
# zenodo.2602109  MCFLIRT                                 MCFLIRT, as implemented in Nipype (modul...         3132
# zenodo.2601876  DTIFit                                  DTIFit, as implemented in Nipype (module...         3083
# zenodo.2566455  BIDS App - FSL Diffusion Preprocessing  Preprocessing pipeline for diffusion MRI...         3074
# zenodo.1450991  fsl_probtrackx2                         probabilistic tracking with crossing fib...         3070
# zenodo.1494312  fsl_first                               FIRST is a model-based segmentation and ...         3059
# zenodo.2597643  FLIRT                                   FLIRT, as implemented in Nipype (module:...         3055
# zenodo.1494308  fsl_fast                                FAST (FMRIB's Automated Segmentation Too...         3042
# zenodo.2639849  FNIRT                                   FNIRT, as implemented in Nipype (module:...         3038

# %% [markdown]
# The `--exact` flag can be used to return descriptor names with the exact spelling

# %%
# !bosh search fsl --exact
# Out:
# [ INFO ] Showing 6 of 6 result(s), exluding 0 deprecated result(s).
# ID              TITLE                                   DESCRIPTION                                    DOWNLOADS
# zenodo.1482743  fsl_bet                                 Automated brain extraction tool for FSL            91083
# zenodo.4472771  fslstats                                Descriptor of fslstats from the FSL tool...        30800
# zenodo.2566455  BIDS App - FSL Diffusion Preprocessing  Preprocessing pipeline for diffusion MRI...         3074
# zenodo.3267250  FslBet601                               Automated brain extraction tool for FSL             2982
# zenodo.3899496  fsl_anat                                General pipeline for processing anatomic...         1338
# zenodo.6139903  fsl_bet-test                            Automated brain extraction tool for FSL               22

# %% [markdown]
# #### BoSh example
#
# In order to be able to run a Boutiques tool, an invocation JSON file is required.
# Invocation files consist of the command parameters/inputs that need to be provided to run the tool.
#
# The `bosh example` command provides an example combination tool parameters in the expected JSON format
#
# Let's get an example invocation of fslstats (zenodo.4472771)

# %%
# !bosh example zenodo.4472771
# Out:
# {
#     "input_file": "f_input_file_69",
#     "H": [
#         -46.95,
#         45.533,
#         -13.959
#     ]
# }

# %% [markdown]
# To get additional optional parameter, the `--complete` flag can be applied

# %%
# !bosh example zenodo.4472771 --complete
# Out:
# {
#     "t": true,
#     "input_file": "f_input_file_64.mnc",
#     "l": -48.163,
#     "u": -26.438,
#     "r": true,
#     "R": true,
#     "e": true,
#     "E": true,
#     "v": true,
#     "V": true,
#     "m": true,
#     "M": true,
#     "s": true,
#     "S": true,
#     "w": true,
#     "x": true,
#     "X": true,
#     "c": true,
#     "C": true,
#     "p": 57,
#     "P": 73,
#     "a": true,
#     "n": true,
#     "k": "f_k_82.nii.gz",
#     "d": "f_d_99.m",
#     "h": 45,
#     "H": [
#         32.841,
#         46.96,
#         -35.848
#     ]
# }

# %% [markdown]
# Today we'll use fslstats to calculate the histogram of one of the bigbrain blocks. We will do that in a new DataLad dataset so that we can publish it easily later:

# %%
# %cd /content
# !datalad create histogram
# %cd histogram
# Out:
# /content
# create(error): /content/histogram (dataset) [will not create a dataset in a non-empty directory, use `--force` option to ignore]
# /content/histogram

# %% [markdown]
# We're just missing the invocation file, so let's create it

# %%
# !echo '{"input_file": "../conp-dataset/projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.nii.gz", "h": 10}' > invocation.json

# %% [markdown]
# #### Launching tools with `bosh exec launch`
#
# Once we know which Boutiques tool we'd like to use and have created a valid invocation, we are ready to launch our tool.
# This can be achieved using the `bosh exec launch` command.

# %%
# !bosh exec launch zenodo.4472771 invocation.json
# Out:
# Shell command
# FSLOUTPUTTYPE=NIFTI_GZ fslstats ../conp-dataset/projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.nii.gz -h 10 > ../conp-dataset/projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.txt
# Container location
#
# Container command
#
# Exit code
# 0
# Error message
#
# Output files
# 	- ../conp-dataset/projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.txt (output, Required)
# Missing files

# %% [markdown]
# The execution produced one file, a text file containing the histogram:

# %%
# !mv ../conp-dataset/projects/BigBrain/3D_Volumes/MNI-ICBM152_Space/nii/full8_400um_2009b_sym.txt .
# !head full8_400um_2009b_sym.txt
# Out:
# 51133.000000
# 128448.000000
# 193710.000000
# 234506.000000
# 324056.000000
# 591447.000000
# 4569486.000000
# 10514099.000000
# 6839354.000000
# 112502948.000000

# %% [markdown]
# Let's finally plot the histogram:

# %%
from matplotlib import pyplot as plt
import numpy as np
hist_data = np.genfromtxt('full8_400um_2009b_sym.txt')
plt.bar(np.arange(len(hist_data[:-1])), hist_data[:-1])
plt.show()

# %% [markdown]
# #### Other useful features
#
# - Boutiques provides a Python API to enable integration of Boutiques tools directly within Python code
# - Integrated into [CBRAIN](http://cbrain.ca/) to enable execution of tools
# - Interfaces with existing neuroimaging pipeline engines such as [Pydra](https://github.com/nipype/pydra) and [TIGR_PURR](https://github.com/TIGRLab/TIGR_PURR)

# %% [markdown]
# <div id="adding"/>
#
# ### (Optional Exercise) Adding derived data to DataLad

# %% [markdown]
# We will publish our newly-created histogram text file as a new DataLad dataset on the [Open Science Framework](https://osf.io/), a research data archive.
#
# To publish our histogram text file as a new DataLad dataset, we first have to save it:

# %%
# !datalad save
# Out:
# Total: 0.00 datasets [00:00, ? datasets/s]
# Total:   0% 0.00/281 [00:00<?, ? Bytes/s]
# Total:  56% 158/281 [00:00<00:00, 936 Bytes/s]
# add(ok): full8_400um_2009b_sym.txt (file)
# add(ok): invocation.json (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 2)
#   save (ok: 1)

# %% [markdown]
# The save command adds a new commit to the dataset containing the newly created text file. We will then declare an OSF "sibling" to our dataset, where we will later push our data. Although our dataset will be publicly accessible on OSF, this step requires an authentication token linked with the OSF account in which the dataset will be deposited (ask the to your instructor) :

# %%
# !OSF_TOKEN=mhvu9AyrQrNGKVMXL8GliD80YyC0rGTdwgtl9gmaexvrpsNxCG41U4czVQ5Z0BIwPl7N0Z datalad create-sibling-osf --title 'HIBALL BigBrain histogram' \
  --mode exportonly \
  -s osf-export \
  --description "This carefully acquired data will bring science forward" \
  --public
# Out:
# create-sibling-osf(ok): https://osf.io/pwk7z/

# %% [markdown]
# Check the URL that was created for your dataset. Note that OSF datasets can also be configured to be private.
#
# We can finally push our dataset to OSF:

# %%
# !OSF_TOKEN=mhvu9AyrQrNGKVMXL8GliD80YyC0rGTdwgtl9gmaexvrpsNxCG41U4czVQ5Z0BIwPl7N0Z git-annex export HEAD --to osf-export-storage
# Out:
# export osf-export-storage .datalad/.gitattributes
# ok
# export osf-export-storage .datalad/config
# ok
# export osf-export-storage .gitattributes
# ok
# export osf-export-storage full8_400um_2009b_sym.txt
# ok
# export osf-export-storage invocation.json
# ok
# (recording state in git...)

# %% [markdown]
# <div id="part2"/>
#
# # Part II: CBRAIN, a web portal to process BigBrain datasets on HPC clusters
#
# CBRAIN is a web portal where you will be able to access the BigBrain dataset and to launch tools on it. No more command-line required! In this tutorial we will launch `BigBrainWarp` on some blocks of the BigBrain dataset.
#
# CBRAIN is one component of the NeuroHub ecosystem of software tools that support neuroinformatics research.
#
# ![screenshot](https://github.com/bryancaron/hws/blob/master/figures/CBRAIN-BigBrain-DataLad-Tutorial-October2022.png?raw=1)
#
# Link to the tutorial slides: [https://docs.google.com/presentation/d/1YXFlPkxiGzUyHpbSzpS8X5RviVaosW0vDI0aZ3UlhIE/edit?usp=sharing](https://docs.google.com/presentation/d/1YXFlPkxiGzUyHpbSzpS8X5RviVaosW0vDI0aZ3UlhIE/edit?usp=sharing)
#
# NeuroHub Portal: [https://portal.neurohub.ca](https://portal.neurohub.ca)

# %% [markdown]
# ## (Optional Exercise) Accessing CBRAIN files with SFTP
#
# We will use SFTP from CBRAIN servers to download result files.
#
# Detailed documentation to interact with CBRAIN using sftp can be found [here](https://portal.cbrain.mcgill.ca/doc/manual/uploading.html).
#
# Let's first create a directory to retrieve our files:

# %%
# %cd /content
# %mkdir cbrain_outputs
# %cd cbrain_outputs

# %% [markdown]
# The following command initiates an interactive sftp session with CBRAIN. Once the connection is established, You will have to type:
# - Your CBRAIN password, to authenticate
# - `get block*`, to download BigBrain blocks
# - `exit`, to end the session

# %%
# !ptyrun sftp -o StrictHostKeyChecking=no -P 7500 YOUR_LOGIN@ace-cbrain-1.cbrain.mcgill.ca

# %% [markdown]
# The files are now available on the local computer:

# %%
# %ls

# %% [markdown]
# # Conclusion
#
# We hope you enjoyed the session! Feel free to reach out to us for any additional information:
#
# [Bryan Caron](mailto:bryan.caron@mcgill.ca), [Natacha Beck](mailto:nbeck@mcin.ca)
#
# Special thanks to [Tristan Glatard](mailto:tristan.glatard@concordia.ca) and [Valérie Hayot-Sasson](mailto:valeriehayot@gmail.com) for creating the original notebook tutorial.
